# %% [markdown]
# # 컴피티션 링크
# - https://www.kaggle.com/t/2e45abe9f1434b59a3358365432a48bb

# %% [markdown]
# # 고객별 백화점 구매기록 데이터셋
# - 미혼(1) or 기혼(0) 고객을 예측
# - 학습용 구매기록 데이터
#     - https://drive.google.com/file/d/1tg41qXu02FK55bFa8P1Gx2URhwPUCoQQ/view?usp=sharing
# - 학습용 정답 데이터
#     - https://drive.google.com/file/d/1-9AcU9nAoO4SzSmqdCOYTvWNpA5Pdt3q/view?usp=sharing
# - 테스트용 구매기록 데이터
#     - https://drive.google.com/file/d/1-AwDfGlHm9rNtpnHIWOK96jBJYy3f2SZ/view?usp=sharing
# - 제출 양식 데이터
#     - https://drive.google.com/file/d/1-Qv7SlsY5Eu3bRR7Z0IUJyLkOO1Fl3y6/view?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 데이터 경로 변수

# %%
DATA_PATH = "/content/drive/MyDrive/final/data/"
DATA_PATH
# Out:
# '/content/drive/MyDrive/final/data/'

# %% [markdown]
# - 데이터 불러오기

# %%
import pandas as pd
import numpy as np

train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr.shape , train_target.shape , test_tr.shape , submit.shape
# Out:
# ((523105, 7), (14940, 2), (441196, 7), (12225, 2))

# %%
from IPython.display import display, HTML
br_html = HTML("<br><br>")
display(HTML("<h1>학습용 구매기록 데이터</h1>"), train_tr.head(), br_html)
display(HTML("<h1>학습용 정답 데이터</h1>"), train_target.head(), br_html)
display(HTML("<h1>테스트용 구매기록 데이터</h1>"), test_tr.head(), br_html)
display(HTML("<h1>제출 양식 데이터</h1>"), submit.head(), br_html)
# Out:
# <h1>학습용 구매기록 데이터</h1>
#             ID                 구매일시     지점코드     대분류      중분류  브랜드코드    구매가격
# 0  train_13219  2004-05-01 09:40:00  A144000   공산품파트       차류   5100   59700
# 1   train_5590  2004-05-01 09:40:00  A144000    잡화파트     화장잡화   5101   17000
# 2   train_7200  2004-05-01 10:20:00  A112000     공산품     용기보증   5100   34937
# 3   train_3010  2004-05-01 10:30:00  A373000  아동_스포츠      아동복   5105   19000
# 4  train_10851  2004-05-01 10:30:00  A112000    가정용품  전화기_카세트   5110  215000
# <br><br>
# <h1>학습용 정답 데이터</h1>
#         ID  target
# 0  train_0     1.0
# 1  train_1     1.0
# 2  train_2     0.0
# 3  train_3     0.0
# 4  train_4     0.0
# <br><br>
# <h1>테스트용 구매기록 데이터</h1>
#           ID                 구매일시     지점코드   대분류      중분류  브랜드코드    구매가격
# 0  test_3366  2004-05-01 10:20:00  A373000   생식품      건식품   5100    7000
# 1  test_9389  2004-05-01 10:23:00  A373000  명품잡화      스타킹   5104   46000
# 2  test_8190  2004-05-01 10:30:00  A144000  잡화파트  수입종합화장품   5106  260000
# 3  test_8835  2004-05-01 10:30:00  A144000  잡화파트      준보석   5107   17000
# 4  test_1167  2004-05-01 10:30:00  A373000  남성의류       셔츠   5108  138000
# <br><br>
# <h1>제출 양식 데이터</h1>
#        ID  target
# 0  test_0     0.5
# 1  test_1     0.5
# 2  test_2     0.5
# 3  test_3     0.5
# 4  test_4     0.5
# <br><br>

# %%
display(HTML("<h1>학습용 구매기록 데이터</h1>"))
display(train_tr.info(), br_html)

display(HTML("<h1>학습용 정답 데이터</h1>"))
display(train_target.info(), br_html)

display(HTML("<h1>테스트용 구매기록 데이터</h1>"))
display(test_tr.info(), br_html)

display(HTML("<h1>제출 양식 데이터</h1>"))
display(submit.info(), br_html)
# Out:
# <h1>학습용 구매기록 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523105 entries, 0 to 523104
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      523105 non-null  object
#  1   구매일시    523105 non-null  object
#  2   지점코드    523105 non-null  object
#  3   대분류     523105 non-null  object
#  4   중분류     523105 non-null  object
#  5   브랜드코드   523105 non-null  int64
#  6   구매가격    523105 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 27.9+ MB
# None
# <br><br>
# <h1>학습용 정답 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14940 entries, 0 to 14939
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      14940 non-null  object
#  1   target  14940 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 233.6+ KB
# None
# <br><br>
# <h1>테스트용 구매기록 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441196 entries, 0 to 441195
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      441196 non-null  object
#  1   구매일시    441196 non-null  object
#  2   지점코드    441196 non-null  object
#  3   대분류     441196 non-null  object
#  4   중분류     441196 non-null  object
#  5   브랜드코드   441196 non-null  int64
#  6   구매가격    441196 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 23.6+ MB
# None
# <br><br>
# <h1>제출 양식 데이터</h1>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12225 entries, 0 to 12224
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      12225 non-null  object
#  1   target  12225 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 191.1+ KB
# None
# <br><br>

# %% [markdown]
# # 피처 추가
# - 구매금액
#   - 요일별 구매가격 합/평균
#   - 평일 구매가격 합/평균, 주말 구매가격 합/평균
#   - 계절별 구매금액 비율

# %% [markdown]
# # 특성 공학(Feature Engineering)

# %% [markdown]
# ## 날짜 형식으로 변환

# %%
train_tr["구매일시"] = pd.to_datetime(train_tr["구매일시"])
test_tr["구매일시"] = pd.to_datetime(test_tr["구매일시"])

train_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523105 entries, 0 to 523104
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      523105 non-null  object
#  1   구매일시    523105 non-null  datetime64[ns]
#  2   지점코드    523105 non-null  object
#  3   대분류     523105 non-null  object
#  4   중분류     523105 non-null  object
#  5   브랜드코드   523105 non-null  int64
#  6   구매가격    523105 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 27.9+ MB

# %% [markdown]
# ## 새로 만든 feature와 병합할 고객ID로만 이루어진 데이터프레임 생성

# %%
train_ft = train_target[["ID"]]
test_ft = submit[["ID"]]

train_ft.shape, test_ft.shape
# Out:
# ((14940, 1), (12225, 1))

# %%
# 초기화 한번에 하기
train_tr = pd.read_csv(f"{DATA_PATH}store_train_transactions.csv") # 학습용 구매기록 데이터
train_target = pd.read_csv(f"{DATA_PATH}store_train.csv") # 학습용 정답 데이터
test_tr = pd.read_csv(f"{DATA_PATH}store_test_transactions.csv") # 테스트용 구매기록 데이터
submit = pd.read_csv(f"{DATA_PATH}store_submission.csv") # 제출 양식 데이터

train_tr["구매일시"] = pd.to_datetime(train_tr["구매일시"])
test_tr["구매일시"] = pd.to_datetime(test_tr["구매일시"])

train_ft = train_target[["ID"]]
test_ft = submit[["ID"]]

# %% [markdown]
# ## 구매일시를 이용한 특성생성

# %%
agg_list = [
        ('내점일수','nunique'),
        ('구매주기', lambda x: int((x.max() - x.min()).days / x.dt.date.nunique())),
        ('월_방문비율', lambda x: np.mean(x.dt.weekday==0)),
        ('화_방문비율', lambda x: np.mean(x.dt.weekday==1)),
        ('수_방문비율', lambda x: np.mean(x.dt.weekday==2)),
        ('목_방문비율', lambda x: np.mean(x.dt.weekday==3)),
        ('금_방문비율', lambda x: np.mean(x.dt.weekday==4)),
        ('주말방문비율', lambda x: np.mean(x.dt.weekday>4)),
        ('18시이전방문비율', lambda x: np.mean(x.dt.hour<18)),#
        ('평일18시이전방문비율', lambda x: (x.dt.weekday < 5).mean()*(x.dt.hour < 18).mean()),#
        ('봄_구매비율', lambda x: np.mean(x.dt.month.isin([3,4,5]))),
        ('여름_구매비율', lambda x: np.mean(x.dt.month.isin([6,7,8]))),
        ('가을_구매비율', lambda x: np.mean(x.dt.month.isin([9,10,11]))),
        ('겨울_구매비율', lambda x: np.mean(x.dt.month.isin([1,2,12]))),
        ('일별평균구매건수', lambda x:  x.count() / x.dt.date.nunique()),
        ('거래개월수', lambda x: x.dt.date.astype(str).str[:-3].nunique()),
]

tmp = train_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
train_ft = train_ft.merge(tmp, how='left',on="ID")
train_ft.head()
# Out:
#         ID  내점일수  구매주기    월_방문비율    화_방문비율    수_방문비율    목_방문비율    금_방문비율  \
# 0  train_0    16    23  0.050000  0.100000  0.250000  0.300000  0.050000
# 1  train_1    41    16  0.047619  0.261905  0.214286  0.333333  0.119048
# 2  train_2   102     6  0.254386  0.201754  0.131579  0.131579  0.070175
# 3  train_3   191     3  0.104265  0.104265  0.161137  0.222749  0.218009
# 4  train_4    55    11  0.096774  0.112903  0.096774  0.048387  0.387097
#
#      주말방문비율  18시이전방문비율  평일18시이전방문비율    봄_구매비율   여름_구매비율   가을_구매비율   겨울_구매비율  \
# 0  0.250000   0.750000     0.562500  0.050000  0.250000  0.400000  0.300000
# 1  0.023810   0.690476     0.674036  0.357143  0.166667  0.357143  0.119048
# 2  0.210526   0.850877     0.671745  0.464912  0.140351  0.175439  0.219298
# 3  0.189573   0.777251     0.629905  0.379147  0.180095  0.236967  0.203791
# 4  0.258065   0.838710     0.622268  0.112903  0.612903  0.209677  0.064516
#
#     겨울_구매비율  일별평균구매건수  거래개월수
# 0  0.300000  1.818182      7
# 1  0.119048  2.000000     11
# 2  0.219298  2.035714     12
# 3  0.203791  2.293478     12
# 4  0.064516  2.296296     10

# %%
tmp = test_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left',on="ID")
test_ft.head()
# Out:
#        ID  내점일수  구매주기    월_방문비율    화_방문비율   수_방문비율   목_방문비율    금_방문비율  \
# 0  test_0     7    32  0.142857  0.285714  0.00000  0.00000  0.000000
# 1  test_1     4    54  0.500000  0.000000  0.25000  0.00000  0.000000
# 2  test_2     4     8  0.600000  0.000000  0.00000  0.40000  0.000000
# 3  test_3    28    16  0.062500  0.062500  0.03125  0.53125  0.281250
# 4  test_4    19    29  0.047619  0.238095  0.00000  0.00000  0.238095
#
#      주말방문비율  18시이전방문비율  평일18시이전방문비율    봄_구매비율   여름_구매비율   가을_구매비율   겨울_구매비율  \
# 0  0.571429   1.000000     0.428571  0.285714  0.285714  0.428571  0.000000
# 1  0.250000   1.000000     0.750000  0.000000  0.000000  0.750000  0.250000
# 2  0.000000   1.000000     1.000000  0.000000  0.600000  0.400000  0.000000
# 3  0.031250   0.468750     0.454102  0.062500  0.468750  0.343750  0.125000
# 4  0.476190   0.428571     0.224490  0.380952  0.285714  0.238095  0.095238
#
#     겨울_구매비율  일별평균구매건수  거래개월수
# 0  0.000000  1.400000      4
# 1  0.250000  1.333333      3
# 2  0.000000  2.500000      2
# 3  0.125000  2.000000      7
# 4  0.095238  2.333333      4

# %%
# agg_list = [
#         # 컬럼명, 집계 방식
#         ('내점일수','nunique'),
#         ('구매주기', lambda x: int( (x.max() - x.min()).days / x.dt.date.nunique()) ),
#         ('주말방문비율', lambda x: np.mean(x.dt.weekday>4)),
#         ('봄_구매비율', lambda x: np.mean(x.dt.month.isin([3,4,5]))),
#         ('여름_구매비율', lambda x: np.mean(x.dt.month.isin([6,7,8]))),
#         ('가을_구매비율', lambda x: np.mean(x.dt.month.isin([9,10,11]))),
#         ('겨울_구매비율', lambda x: np.mean(x.dt.month.isin([1,2,12]))),
#         ('주구매요일', lambda x: x.dt.weekday.mode()[0]),
#         ('일별평균구매건수', lambda x:  x.count() / x.dt.date.nunique() ),
#         ('거래개월수', lambda x: x.dt.date.astype(str).str[:-3].nunique() ),
#     ]

# tmp = train_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
# train_ft = train_ft.merge(tmp, how='left',on="ID")
# train_ft.head()

# %%
# tmp = test_tr.groupby('ID')["구매일시"].agg(agg_list).reset_index()
# test_ft = test_ft.merge(tmp, how='left',on="ID")
# test_ft.head()

# %% [markdown]
# ## 지점을 이용한 특성생성

# %%
# agg_list = [
#           ("방문지점수","nunique"),
#           ('주구매지점', lambda x: x.mode()[0]),
#     ]

# tmp = train_tr.groupby('ID')["지점코드"].agg(agg_list).reset_index()
# train_ft = train_ft.merge(tmp, how='left',on="ID")
# train_ft.head()

# %%
# tmp = test_tr.groupby('ID')["지점코드"].agg(agg_list).reset_index()
# test_ft = test_ft.merge(tmp, how='left',on="ID")
# test_ft.head()

# %% [markdown]
# ## 브랜드코드를 이용한 특성생성

# %%
agg_list = [
    ('브랜드코드_nunique', 'nunique'),
    ('주구매_브랜드코드', lambda x: x.mode()[0])
]

tmp = train_tr.groupby('ID')["브랜드코드"].agg(agg_list).reset_index()
train_ft = train_ft.merge(tmp, how='left',on="ID")
train_ft.head()
# Out:
#         ID  내점일수  구매주기    월_방문비율    화_방문비율    수_방문비율    목_방문비율    금_방문비율  \
# 0  train_0    16    23  0.050000  0.100000  0.250000  0.300000  0.050000
# 1  train_1    41    16  0.047619  0.261905  0.214286  0.333333  0.119048
# 2  train_2   102     6  0.254386  0.201754  0.131579  0.131579  0.070175
# 3  train_3   191     3  0.104265  0.104265  0.161137  0.222749  0.218009
# 4  train_4    55    11  0.096774  0.112903  0.096774  0.048387  0.387097
#
#      주말방문비율  18시이전방문비율  평일18시이전방문비율    봄_구매비율   여름_구매비율   가을_구매비율   겨울_구매비율  \
# 0  0.250000   0.750000     0.562500  0.050000  0.250000  0.400000  0.300000
# 1  0.023810   0.690476     0.674036  0.357143  0.166667  0.357143  0.119048
# 2  0.210526   0.850877     0.671745  0.464912  0.140351  0.175439  0.219298
# 3  0.189573   0.777251     0.629905  0.379147  0.180095  0.236967  0.203791
# 4  0.258065   0.838710     0.622268  0.112903  0.612903  0.209677  0.064516
#
#     겨울_구매비율  일별평균구매건수  거래개월수  브랜드코드_nunique  주구매_브랜드
# 0  0.300000  1.818182      7             13     5452
# 1  0.119048  2.000000     11             26     5100
# 2  0.219298  2.035714     12             58     5159
# 3  0.203791  2.293478     12             99     5138
# 4  0.064516  2.296296     10             23     5100

# %%
tmp = test_tr.groupby('ID')["브랜드코드"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left',on="ID")
test_ft.head()
# Out:
#        ID  내점일수  구매주기    월_방문비율    화_방문비율   수_방문비율   목_방문비율    금_방문비율  \
# 0  test_0     7    32  0.142857  0.285714  0.00000  0.00000  0.000000
# 1  test_1     4    54  0.500000  0.000000  0.25000  0.00000  0.000000
# 2  test_2     4     8  0.600000  0.000000  0.00000  0.40000  0.000000
# 3  test_3    28    16  0.062500  0.062500  0.03125  0.53125  0.281250
# 4  test_4    19    29  0.047619  0.238095  0.00000  0.00000  0.238095
#
#      주말방문비율  18시이전방문비율  평일18시이전방문비율    봄_구매비율   여름_구매비율   가을_구매비율   겨울_구매비율  \
# 0  0.571429   1.000000     0.428571  0.285714  0.285714  0.428571  0.000000
# 1  0.250000   1.000000     0.750000  0.000000  0.000000  0.750000  0.250000
# 2  0.000000   1.000000     1.000000  0.000000  0.600000  0.400000  0.000000
# 3  0.031250   0.468750     0.454102  0.062500  0.468750  0.343750  0.125000
# 4  0.476190   0.428571     0.224490  0.380952  0.285714  0.238095  0.095238
#
#     겨울_구매비율  일별평균구매건수  거래개월수  브랜드코드_nunique  주구매_브랜드
# 0  0.000000  1.400000      4              5     5100
# 1  0.250000  1.333333      3              4     5149
# 2  0.000000  2.500000      2              5     5111
# 3  0.125000  2.000000      7             19     5111
# 4  0.095238  2.333333      4             13     5204

# %% [markdown]
# ## 중분류를 이용한 특성생성

# %%
agg_list = [
            ('중분류_nunique', 'nunique'),
            ('주구매_중분류', lambda x: x.mode()[0]),
            ]
tmp = train_tr.groupby('ID')["중분류"].agg(agg_list).reset_index()
train_ft = train_ft.merge(tmp, how='left')
train_ft.head()
# Out:
#         ID  내점일수  구매주기    월_방문비율    화_방문비율    수_방문비율    목_방문비율    금_방문비율  \
# 0  train_0    16    23  0.050000  0.100000  0.250000  0.300000  0.050000
# 1  train_1    41    16  0.047619  0.261905  0.214286  0.333333  0.119048
# 2  train_2   102     6  0.254386  0.201754  0.131579  0.131579  0.070175
# 3  train_3   191     3  0.104265  0.104265  0.161137  0.222749  0.218009
# 4  train_4    55    11  0.096774  0.112903  0.096774  0.048387  0.387097
#
#      주말방문비율  18시이전방문비율  ...   여름_구매비율   가을_구매비율   겨울_구매비율   겨울_구매비율  일별평균구매건수  \
# 0  0.250000   0.750000  ...  0.250000  0.400000  0.300000  0.300000  1.818182
# 1  0.023810   0.690476  ...  0.166667  0.357143  0.119048  0.119048  2.000000
# 2  0.210526   0.850877  ...  0.140351  0.175439  0.219298  0.219298  2.035714
# 3  0.189573   0.777251  ...  0.180095  0.236967  0.203791  0.203791  2.293478
# 4  0.258065   0.838710  ...  0.612903  0.209677  0.064516  0.064516  2.296296
#
#    거래개월수  브랜드코드_nunique  주구매_브랜드  중분류_nunique  주구매_중분류
# 0      7             13     5452           11     골프웨어
# 1     11             26     5100           24     영캐주얼
# 2     12             58     5159           35     아웃도어
# 3     12             99     5138           60  수입종합화장품
# 4     10             23     5100           24   로얄부틱2F
#
# [5 rows x 22 columns]

# %%
tmp = test_tr.groupby('ID')["중분류"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left')
test_ft.head()
# Out:
#        ID  내점일수  구매주기    월_방문비율    화_방문비율   수_방문비율   목_방문비율    금_방문비율  \
# 0  test_0     7    32  0.142857  0.285714  0.00000  0.00000  0.000000
# 1  test_1     4    54  0.500000  0.000000  0.25000  0.00000  0.000000
# 2  test_2     4     8  0.600000  0.000000  0.00000  0.40000  0.000000
# 3  test_3    28    16  0.062500  0.062500  0.03125  0.53125  0.281250
# 4  test_4    19    29  0.047619  0.238095  0.00000  0.00000  0.238095
#
#      주말방문비율  18시이전방문비율  ...   여름_구매비율   가을_구매비율   겨울_구매비율   겨울_구매비율  일별평균구매건수  \
# 0  0.571429   1.000000  ...  0.285714  0.428571  0.000000  0.000000  1.400000
# 1  0.250000   1.000000  ...  0.000000  0.750000  0.250000  0.250000  1.333333
# 2  0.000000   1.000000  ...  0.600000  0.400000  0.000000  0.000000  2.500000
# 3  0.031250   0.468750  ...  0.468750  0.343750  0.125000  0.125000  2.000000
# 4  0.476190   0.428571  ...  0.285714  0.238095  0.095238  0.095238  2.333333
#
#    거래개월수  브랜드코드_nunique  주구매_브랜드  중분류_nunique  주구매_중분류
# 0      4              5     5100            4     용기보증
# 1      3              4     5149            4     남성구두
# 2      2              5     5111            4  수입종합화장품
# 3      7             19     5111           12  수입종합화장품
# 4      4             13     5204           12  칼라드래디셔널
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 대분류를 이용한 특성생성

# %%
agg_list = [
            ('대분류_nunique', 'nunique'),
            ('주구매_대분류', lambda x: x.mode()[0]),
            ]

tmp = train_tr.groupby('ID')["대분류"].agg(agg_list).reset_index()
train_ft = train_ft.merge(tmp, how='left')
train_ft.head()
# Out:
#         ID  내점일수  구매주기    월_방문비율    화_방문비율    수_방문비율    목_방문비율    금_방문비율  \
# 0  train_0    16    23  0.050000  0.100000  0.250000  0.300000  0.050000
# 1  train_1    41    16  0.047619  0.261905  0.214286  0.333333  0.119048
# 2  train_2   102     6  0.254386  0.201754  0.131579  0.131579  0.070175
# 3  train_3   191     3  0.104265  0.104265  0.161137  0.222749  0.218009
# 4  train_4    55    11  0.096774  0.112903  0.096774  0.048387  0.387097
#
#      주말방문비율  18시이전방문비율  ...   겨울_구매비율   겨울_구매비율  일별평균구매건수  거래개월수  \
# 0  0.250000   0.750000  ...  0.300000  0.300000  1.818182      7
# 1  0.023810   0.690476  ...  0.119048  0.119048  2.000000     11
# 2  0.210526   0.850877  ...  0.219298  0.219298  2.035714     12
# 3  0.189573   0.777251  ...  0.203791  0.203791  2.293478     12
# 4  0.258065   0.838710  ...  0.064516  0.064516  2.296296     10
#
#    브랜드코드_nunique  주구매_브랜드  중분류_nunique  주구매_중분류  대분류_nunique    주구매_대분류
# 0             13     5452           11     골프웨어            9    남성정장스포츠
# 1             26     5100           24     영캐주얼           12       영플라자
# 2             58     5159           35     아웃도어           14       명품잡화
# 3             99     5138           60  수입종합화장품           16  케주얼_구두_아동
# 4             23     5100           24   로얄부틱2F            8       명품잡화
#
# [5 rows x 24 columns]

# %%
tmp = test_tr.groupby('ID')["대분류"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left')
test_ft.head()
# Out:
#        ID  내점일수  구매주기    월_방문비율    화_방문비율   수_방문비율   목_방문비율    금_방문비율  \
# 0  test_0     7    32  0.142857  0.285714  0.00000  0.00000  0.000000
# 1  test_1     4    54  0.500000  0.000000  0.25000  0.00000  0.000000
# 2  test_2     4     8  0.600000  0.000000  0.00000  0.40000  0.000000
# 3  test_3    28    16  0.062500  0.062500  0.03125  0.53125  0.281250
# 4  test_4    19    29  0.047619  0.238095  0.00000  0.00000  0.238095
#
#      주말방문비율  18시이전방문비율  ...   겨울_구매비율   겨울_구매비율  일별평균구매건수  거래개월수  \
# 0  0.571429   1.000000  ...  0.000000  0.000000  1.400000      4
# 1  0.250000   1.000000  ...  0.250000  0.250000  1.333333      3
# 2  0.000000   1.000000  ...  0.000000  0.000000  2.500000      2
# 3  0.031250   0.468750  ...  0.125000  0.125000  2.000000      7
# 4  0.476190   0.428571  ...  0.095238  0.095238  2.333333      4
#
#    브랜드코드_nunique  주구매_브랜드  중분류_nunique  주구매_중분류  대분류_nunique  주구매_대분류
# 0              5     5100            4     용기보증            5      공산품
# 1              4     5149            4     남성구두            3     명품잡화
# 2              5     5111            4  수입종합화장품            3     잡화파트
# 3             19     5111           12  수입종합화장품            5     영플라자
# 4             13     5204           12  칼라드래디셔널            6    여성캐주얼
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 구매가격을 이용한 특성생성

# %%
agg_list = [
        ('총구매액','sum'),
        ('구매건수', 'count'),
        ('평균구매액', "mean"),
        ('최대구매액', 'max'),
        ('최소구매액',lambda x: x[x > 0].min()),
        ('총환불금액',lambda x: x[x < 0].sum()),
        ('환불건수', lambda x: (x < 0).sum()),
        ('구매대비환불비율', lambda x: ((x < 0).sum() / x.count())),#
        ('구매금액표준편차',lambda x: x[x>0].std()),
        ('구매금액왜도',lambda x: x[x>0].skew()),
        ('월_구매금액_mean', ),

        # ('평일_구매금액_mean', ),
        # ('주말_구매금액_mean', ),
        # ('봄_구매금액_mean', )
]

train_tr.groupby('ID')["구매가격"].agg(agg_list).reset_index()
# tmp = train_tr.groupby('ID')["구매가격"].agg(agg_list).reset_index()
# train_ft = train_ft.merge(tmp, how='left')
# train_ft.head()
# Out:
#                ID      총구매액  구매건수          평균구매액    최대구매액  최소구매액    총환불금액  \
# 0         train_0   4201200    20  210060.000000  1236000  20000 -2517000
# 1         train_1   5043025    42  120072.023810   698000   5600        0
# 2        train_10  11234870   134   83842.313433   907000   2500  -192750
# 3       train_100   1875887    26   72149.500000   478000  10767  -397200
# 4      train_1000    757500    45   16833.333333   324500  12000 -1710600
# ...           ...       ...   ...            ...      ...    ...      ...
# 14935  train_9995     36000     1   36000.000000    36000  36000        0
# 14936  train_9996   4774410    25  190976.400000  1980000  21500   -84000
# 14937  train_9997    795700    27   29470.370370   154000   6000  -388300
# 14938  train_9998   2069325    29   71356.034483   279000   6500        0
# 14939  train_9999   6970530    36  193625.833333  2241630   9000  -539000
#
#        환불건수  구매대비환불비율       구매금액표준편차    구매금액왜도
# 0         3  0.150000  403660.245259  1.183078
# 1         0  0.000000  126592.626144  2.651821
# 2         3  0.022388  142331.010505  4.252053
# 3         3  0.115385  100152.898331  2.733265
# 4        15  0.333333   70680.486260  1.860956
# ...     ...       ...            ...       ...
# 14935     0  0.000000            NaN       NaN
# 14936     1  0.040000  386579.676402  4.585697
# 14937     6  0.222222   46034.081060  0.984801
# 14938     0  0.000000   64165.861742  1.556740
# 14939     4  0.111111  458339.332712  3.668234
#
# [14940 rows x 11 columns]

# %%
tmp = test_tr.groupby('ID')["구매가격"].agg(agg_list).reset_index()
test_ft = test_ft.merge(tmp, how='left')
test_ft.head()

# %% [markdown]
# ## pivot_table을 이용한 특성 생성

# %%
# train_tmp = pd.pivot_table(train_tr,index="ID",columns="중분류",values="구매가격",aggfunc="count",fill_value=0).add_prefix("pivot_cnt_").reset_index()
# train_ft = train_ft.merge(train_tmp,how="left",on="ID")
# train_ft.head()

# %%
# test_tmp = pd.pivot_table(test_tr,index="ID",columns="중분류",values="구매가격",aggfunc="count",fill_value=0).add_prefix("pivot_cnt_").reset_index()
# test_tmp.head()

# %%
# 학습데이터 컬럼 기준으로 컬럼 맞추기(학습데이터 또는 테스트데이터에 있는 값이 반대에는 없는 경우)
# for col in train_tmp.columns:
#     if col not in test_tmp.columns:
#         test_tmp[col] = 0

# test_tmp = test_tmp[train_tmp.columns]

# %%
# test_ft = test_ft.merge(test_tmp,how="left",on="ID")
# test_ft.head()

# %% [markdown]
# # 항상 확인하기
# - 학습데이터와 테스트 데이터의 피처개수는 동일해야 함

# %%
train_ft.shape, test_ft.shape
# Out:
# ((14940, 24), (12225, 24))

# %% [markdown]
# # 추출한 피처 저장하기

# %%
train_ft.to_csv(f"{DATA_PATH}train_common.csv",index=False)
test_ft.to_csv(f"{DATA_PATH}test_common.csv",index=False)
